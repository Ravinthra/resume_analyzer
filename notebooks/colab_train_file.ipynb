# %%
import os
from google.colab import userdata
from huggingface_hub import login

HF_TOKEN = userdata.get("HF_TOKEN")

login(token=HF_TOKEN)
os.environ["HF_TOKEN"] = HF_TOKEN

print("HuggingFace login successful")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# HuggingFace login successful

# %%
# !nvidia-smi
# Out:
# Thu Mar 19 07:01:29 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             10W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-421c1668-8fab-4e9f-aca1-447254c64356" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-421c1668-8fab-4e9f-aca1-447254c64356">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q DEMO.zip

# %%
# !pip install -q transformers torch scikit-learn pandas matplotlib seaborn pdfplumber

# %%
# %cd DEMO
# Out:
# /content/DEMO/DEMO/DEMO

# %%
# !python scripts/colab_train.py
# Out:
# ...
# COLAB SETUP
# ...
# GPU: Tesla T4
# All dependencies already installed
# Environment ready
# Generating dataset …
#   [ 1/25] Data Scientist                 — 3800 files  (1.4s)
#   [ 2/25] Software Engineer              — 3800 files  (2.6s)
#   [ 3/25] Web Developer                  — 3800 files  (3.9s)
#   [ 4/25] DevOps Engineer                — 3800 files  (5.1s)
#   [ 5/25] ML Engineer                    — 3800 files  (6.4s)
#   [ 6/25] Data Analyst                   — 3800 files  (7.6s)
#   [ 7/25] Backend Developer              — 3800 files  (8.8s)
#   [ 8/25] Frontend Developer             — 3800 files  (10.1s)
#   [ 9/25] Full Stack Developer           — 3800 files  (11.8s)
#   [10/25] Database Administrator         — 3800 files  (13.7s)
#   [11/25] System Administrator           — 3800 files  (14.9s)
#   [12/25] Network Engineer               — 3800 files  (16.1s)
#   [13/25] Cybersecurity Analyst          — 3800 files  (17.5s)
# ...

# %%
file_path = 'scripts/colab_train.py'

with open(file_path, 'r') as f:
    content = f.read()

# Replace 'total_mem' with 'total_memory'
modified_content = content.replace('total_mem', 'total_memory')

with open(file_path, 'w') as f:
    f.write(modified_content)

print(f"Successfully patched {file_path}. Replaced 'total_mem' with 'total_memory'.")
# Out:
# Successfully patched scripts/colab_train.py. Replaced 'total_mem' with 'total_memory'.

# %%
files.download('models/bert_classifier.pt')
